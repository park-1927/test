# %% [markdown]
# <a href="https://colab.research.google.com/github/park-1927/test/blob/main/ColabUsage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#GPU 정보 출력시
#런 타임 유형을 GPU로 설정
#NVIDIA GPU 보는법(nvidia-smi) - https://velog.io/@claude_ssim/NVIDIA-GPU-%EB%B3%B4%EB%8A%94%EB%B2%95nvidia-smi
#Computed Unified Device Architecture(CUDA)는 GPU에서 수행하는 병렬 연산을 프로그래밍 언어로 작성하여 수행할 수 있게 하는 기술임.
# !pip install --upgrade nvidia-pyindex
# !nvidia-smi

# %%
#CPU 정보 출력 시
# !head /proc/cpuinfo

# %%
#우분투 버젼
# !cat /etc/issue

# %%
#RAM 정보
# !head -n 3 /proc/meminfo

# %%
#파이썬 버젼
import sys
print(sys.version)

# %%
#텐서플로우 버젼
#텐서플로는 구글에서 만든 딥러닝 프로그램을 쉽게 구현할 수 있도록 기능을 제공하는 라이브러리.
import tensorflow as tf
print(tf.__version__)

# %%
#구글 코랩 파일 업로드하기--https://m.blog.naver.com/towards-ai/222184695026
# !pwd
#Mount drive를 클릭하면 생성되는 기본 코드임
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ![코랩파일마운트.png](data:image/png;base64,...)

# %%
#원하는 mount link로 마운트 가능
import os
os.chdir('drive/MyDrive')
# !ls

# %%
#또 다른 mount 예
#Google Drive를 마운트하면 Colab 환경에서 Google Drive의 파일 및 폴더에 액세스할 수 있음
#force_remount=True 매개변수는 Google Drive를 강제로 다시 마운트하도록 지정함
#이렇게 함으로써 이전에 마운트된 Google Drive가 있다면 덮어씀
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
os.chdir('drive/MyDrive/Colab Notebooks')
# !pwd

# %%
#choose file을 이용하여 업로드하는 방법--https://m.blog.naver.com/towards-ai/222184695026
from google.colab import files
files.upload()

# %%
Link="/content/drive/MyDrive/Colab Notebooks/퍼셉트론.ipynb"
# !cat 퍼셉트론.ipynb

# %%
#구글 콜랩(Google Colab) Code snippets - 재사용 가능한 소스 코드
#자주 사용하는 코드들은 검색을 통해 간단한 수정이 바로 사용 가능함
#반복 타이핑을 회피할 수 있게 도와줌--https://m.blog.naver.com/towards-ai/222184695026

# %%
#Multicursor 지원--Alt+shift key
print("1")
print("2")
print("3")

# %%
#마크다운 줄바꿈
#입력 시 적당한 길이에서 스페이스바를 두번 입력 후 엔터를 치면 줄바꿈이 이루이짐
#입력 완료 후에는 shift_Enter를 치면 됨
#https://umking.tistory.com/41

# %% [markdown]
# #인공지능
# 소개

# %%
#라이브러리 설치
# !pip install numpy pandas matplotlib

# %%
import matplotlib.pyplot as plt
x=[1, 2, 3, 4, 5]
y=[2, 3, 5, 7, 11]
plt.rc('font', family='NanumBarunGothic')
plt.plot(x, y)
plt.xlabel('X축')
plt.ylabel('Y축')
plt.title('간단한 선 그래프')
plt.show()

# %%
#구글 colab에서 시각화 라이브러리(matplotlib, seaborn)을 사용하게 되면 한글 깨짐 현상
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#런타임 - 런타임 다시 시작 을 클릭하여 런타임을 재시작
#plt.rc('font', family='NanumBarunGothic')를 추가
